# %%
import pims
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import glob
import json

# %matplotlib notebook
# %matplotlib notebook

# %%
frames = pims.open('./data/plt1.png')

# %%
with open('./data/plt1.txt', 'r') as file:
    meta = np.loadtxt(file)

# %%
frames[0]
# Out:
# Frame([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
plt.imshow(frames[0])
# Out:
# <img src="data:image/png;base64,..." width="639.6">

# %% [markdown]
# What is the bbox for the '4.50' tick mark as measured by the image?
# x0=69.7
# y0=363.1, or 36.9 (origin lower)
# x1=96.7
# y1=349.1 or 50.94 (origin lower)

# %%
plt.imshow(np.flipud(frames[0]), origin='lower')

# %%
meta.T[2]*400
# Out:
# array([ 41.55555556,  41.55555556,  41.55555556,  41.55555556,
#         69.49619128, 105.91590922, 142.33562716, 178.7553451 ,
#        215.17506304, 251.59478098, 288.01449892, 324.43421686,
#        360.8539348 ])

# %%
frames[0].shape
# Out:
# (400, 400, 4)

# %%
meta*400
# Out:
# array([[  0.        ,  78.79048277, 358.44444444,  42.375     ,
#          14.        ],
#        [  0.        , 127.28840711, 358.44444444,  42.375     ,
#          14.        ],
#        [  0.        , 175.78633145, 358.44444444,  30.625     ,
#          14.        ],
#        [  0.        , 224.28425579, 358.44444444,  30.75      ,
#          14.        ],
#        [  0.        , 272.78218013, 358.44444444,  30.75      ,
#          14.        ],
#        [  0.        , 321.28010447, 358.44444444,  30.75      ,
#          14.        ],
#        [  0.        , 369.77802881, 358.44444444,  30.75      ,
#          14.        ],
#        [400.        ,  50.05555556, 308.59209391,  30.75      ,
#          14.        ],
#        [400.        ,  50.05555556, 269.62645305,  30.75      ,
#          14.        ],
#        [400.        ,  50.05555556, 230.66081218,  30.75      ,
#          14.        ],
#        [400.        ,  49.99305556, 191.69517131,  30.875     ,
# ...
